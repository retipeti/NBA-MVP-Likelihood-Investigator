# %% [markdown]
# # Modeling

# %% [markdown]
# This notebook is responsible for the modeling part of the project where I would like to investigate how individual and team performance metrics influence a player’s likelihood of winning the NBA Most Valuable Player (MVP) award during the regular season.
#
# As this is just a test project where the focus is not on the code itself, this is empty.
