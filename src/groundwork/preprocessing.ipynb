# %% [markdown]
# # Preprocessing

# %% [markdown]
# This notebook is responsible for the full preprocessing pipeline of the project.
#
# In this case it is only responsible for creating a dummy processed dataset as part of the exercise.
#
# In reality it would be responsible to collect, merge and preprocess the datasets necessary for further analysis.

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Creating processed dataset

# %%
# Paths (adjust if your structure is different)
DATA_RAW = Path("../../data/raw")
DATA_PROCESSED = Path("../../data/processed")

Input_File = DATA_RAW / "PlayerStatistics.csv"

df = pd.read_csv(Input_File)
processed_df = df.head(3)
processed_df.to_csv(DATA_PROCESSED/"Processed_Stat.csv")
# Out:
# /var/folders/b6/1mflrv1s5s9b5pj5n4cg2hjw0000gn/T/ipykernel_34615/1905199728.py:7: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(Input_File)
